# %%
from recommendation_engine import *

# %%
get_scores('46115B')
# Out:
#      StockCode                             Desc  UnitPrice     score
# 34       16043        POP ART PUSH DOWN RUBBER        0.12  0.311027
# 2575    47518F      ICON PLACEMAT POP ART ELVIS       0.42  0.270921
# 2198     23396          BUTTERFLY CUSHION COVER       3.75  0.263932
# 3099    84984A        GREEN PEONY CUSHION COVER       4.65  0.256492
# 152      20700  GREEN CAT FLORAL CUSHION COVER        3.75  0.230984
# 3045    84910A      PINK PAISLEY CUSHION COVER        5.95  0.229159
# 3042     84905    PINK BUTTERFLY CUSHION COVER        4.95  0.225140
# 3053     84919   BLUE CUSHION COVER WITH FLOWER       6.95  0.219001
# 229      20836     FRENCH PAISLEY CUSHION COVER       0.83  0.215651
# 232      20839    FRENCH PAISLEY CUSHION COVER        2.95  0.215651

# %%
fav_clients('46115B').reset_index()
# Out:
#    CustomerID        rate
# 0       14298  104.033851
# 1       18041   40.881187
# 2       15241   26.008463
# 3       13694   23.016001
# 4       12576   13.994788

# %%
colab_filter(14298,'46115B').reset_index()
# Out:
#    index StockCode                             Desc  UnitPrice
# 0   2575    47518F      ICON PLACEMAT POP ART ELVIS       0.42
# 1    232     20839    FRENCH PAISLEY CUSHION COVER        2.95
# 2    229     20836     FRENCH PAISLEY CUSHION COVER       0.83
# 3   3099    84984A        GREEN PEONY CUSHION COVER       4.65
# 4    152     20700  GREEN CAT FLORAL CUSHION COVER        3.75
